# %%
import mnist_loader
training_data, validation_data, test_data, train_for_error_data = mnist_loader.load_data_wrapper()

# %%
import network2

# %%
net = network2.Network([784, 30, 10], cost=network2.CrossEntropyCost)

# %%
net.SGD(training_data, 30, 10, 0.1, lmbda = 5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True, monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Accuracy on training data: 46093 / 50000
# Accuracy on evaluation data: 9281 / 10000
#
# Epoch 1 training complete
# Accuracy on training data: 46761 / 50000
# Accuracy on evaluation data: 9404 / 10000
#
# Epoch 2 training complete
# Accuracy on training data: 47201 / 50000
# Accuracy on evaluation data: 9469 / 10000
#
# Epoch 3 training complete
# Accuracy on training data: 47512 / 50000
# Accuracy on evaluation data: 9512 / 10000
#
# Epoch 4 training complete
# Accuracy on training data: 47640 / 50000
# Accuracy on evaluation data: 9509 / 10000
#
# Epoch 5 training complete
# Accuracy on training data: 47868 / 50000
# Accuracy on evaluation data: 9539 / 10000
#
# Epoch 6 training complete
# Accuracy on training data: 47984 / 50000
# Accuracy on evaluation data: 9534 / 10000
#
# Epoch 7 training complete
# Accuracy on training data: 47980 / 50000
# Accuracy on evaluation data: 9540 / 10000
#
# Epoch 8 training complete
# Accuracy on training data: 48082 / 50000
# Accuracy on evaluation data: 9561 / 10000
#
# Epoch 9 training complete
# Accuracy on training data: 48268 / 50000
# Accuracy on evaluation data: 9586 / 10000
#
# Epoch 10 training complete
# Accuracy on training data: 48294 / 50000
# Accuracy on evaluation data: 9570 / 10000
#
# Epoch 11 training complete
# Accuracy on training data: 48291 / 50000
# Accuracy on evaluation data: 9591 / 10000
#
# Epoch 12 training complete
# Accuracy on training data: 48389 / 50000
# Accuracy on evaluation data: 9572 / 10000
#
# Epoch 13 training complete
# Accuracy on training data: 48437 / 50000
# Accuracy on evaluation data: 9591 / 10000
#
# Epoch 14 training complete
# Accuracy on training data: 48491 / 50000
# Accuracy on evaluation data: 9588 / 10000
#
# Epoch 15 training complete
# Accuracy on training data: 48510 / 50000
# Accuracy on evaluation data: 9603 / 10000
#
# Epoch 16 training complete
# Accuracy on training data: 48598 / 50000
# Accuracy on evaluation data: 9600 / 10000
#
# Epoch 17 training complete
# Accuracy on training data: 48562 / 50000
# Accuracy on evaluation data: 9592 / 10000
#
# Epoch 18 training complete
# Accuracy on training data: 48622 / 50000
# Accuracy on evaluation data: 9595 / 10000
#
# Epoch 19 training complete
# Accuracy on training data: 48569 / 50000
# Accuracy on evaluation data: 9615 / 10000
#
# Epoch 20 training complete
# Accuracy on training data: 48629 / 50000
# Accuracy on evaluation data: 9606 / 10000
#
# Epoch 21 training complete
# Accuracy on training data: 48716 / 50000
# Accuracy on evaluation data: 9619 / 10000
#
# Epoch 22 training complete
# Accuracy on training data: 48640 / 50000
# Accuracy on evaluation data: 9622 / 10000
#
# Epoch 23 training complete
# Accuracy on training data: 48701 / 50000
# Accuracy on evaluation data: 9619 / 10000
#
# Epoch 24 training complete
# Accuracy on training data: 48706 / 50000
# Accuracy on evaluation data: 9611 / 10000
#
# Epoch 25 training complete
# Accuracy on training data: 48699 / 50000
# Accuracy on evaluation data: 9619 / 10000
#
# Epoch 26 training complete
# Accuracy on training data: 48711 / 50000
# Accuracy on evaluation data: 9620 / 10000
#
# Epoch 27 training complete
# Accuracy on training data: 48800 / 50000
# Accuracy on evaluation data: 9630 / 10000
#
# Epoch 28 training complete
# Accuracy on training data: 48769 / 50000
# Accuracy on evaluation data: 9611 / 10000
#
# Epoch 29 training complete
# Accuracy on training data: 48806 / 50000
# Accuracy on evaluation data: 9643 / 10000
# ([],
#  [9281,
#   9404,
#   9469,
#   9512,
#   9509,
#   9539,
#   9534,
#   9540,
#   9561,
#   9586,
#   9570,
#   9591,
#   9572,
#   9591,
#   9588,
#   9603,
#   9600,
#   9592,
#   9595,
#   9615,
#   9606,
#   9619,
#   9622,
#   9619,
#   9611,
#   9619,
#   9620,
#   9630,
#   9611,
#   9643],
#  [],
#  [46093,
#   46761,
#   47201,
#   47512,
#   47640,
#   47868,
#   47984,
#   47980,
#   48082,
#   48268,
#   48294,
#   48291,
#   48389,
#   48437,
#   48491,
#   48510,
#   48598,
#   48562,
#   48622,
#   48569,
#   48629,
#   48716,
#   48640,
#   48701,
#   48706,
#   48699,
#   48711,
#   48800,
#   48769,
#   48806])
